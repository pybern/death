# %%
import pandas as pd
import json
from pyelasticsearch import ElasticSearch
import nltk 
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import re
from textblob import TextBlob
import os

# %%
x = os.path.abspath('info.json')

# %%
x
# Out:
# 'D:\\death\\death\\texasdeath\\info.json'

# %%
data = pd.read_json(x)

def colNames(data):
    colNames = (list(data.columns.values))
    return colNames

colNames(data)    

data['MessageWords'] = ""
data['DescriptionWords'] = ""
data['MessageSenti'] = ""
data['DescriptionSenti'] = ""

def review_to_words( raw_review ):
    review_text = BeautifulSoup(raw_review).get_text() 
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    words = letters_only.lower().split()                             
    stops = set(stopwords.words("english"))                  
    meaningful_words = [w for w in words if not w in stops]   
    return( " ".join( meaningful_words ))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ef0602c74594> in <module>()
# ----> 1 data = pd.read_json(x)
#       2
#       3 def colNames(data):
#       4     colNames = (list(data.columns.values))
#       5     return colNames
#
# c:\anaconda2\envs\death\lib\site-packages\pandas\io\json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     209         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     210                           keep_default_dates, numpy, precise_float,
# --> 211                           date_unit).parse()
#     212
#     213     if typ == 'series' or obj is None:
#
# c:\anaconda2\envs\death\lib\site-packages\pandas\io\json.pyc in parse(self)
#     277
#     278         else:
# --> 279             self._parse_no_numpy()
#     280
#     281         if self.obj is None:
#
# c:\anaconda2\envs\death\lib\site-packages\pandas\io\json.pyc in _parse_no_numpy(self)
#     494         if orient == "columns":
#     495             self.obj = DataFrame(
# --> 496                 loads(json, precise_float=self.precise_float), dtype=None)
#     497         elif orient == "split":
#     498             decoded = dict((str(k), v)
#
# ValueError: Expected object or value

# %%
colNames(data)
# Out:
# [u'Age',
#  u'County',
#  u'Date',
#  u'Description',
#  u'Education',
#  u'Message',
#  u'Mid',
#  u'OILink',
#  u'OLastStatement',
#  u'Race',
#  u'firstName',
#  u'lastName',
#  'MessageWords',
#  'DescriptionWords',
#  'MessageSenti',
#  'DescriptionSenti']

# %%
text = "Texas Department of Justice"
TextBlob(text).sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
dataLen = len(data)

for i in range (0,dataLen):
    data['MessageWords'][i] = review_to_words(data["Message"][i])
    data['DescriptionWords'][i] = review_to_words(data["Description"][i])
    data['MessageSenti'][i] = TextBlob(data["MessageWords"][i]).sentiment[0]
    data['DescriptionSenti'][i] = TextBlob(data["DescriptionWords"][i]).sentiment[0]
# Out:
# c:\anaconda2\envs\death\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# c:\anaconda2\envs\death\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\anaconda2\envs\death\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\anaconda2\envs\death\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\anaconda2\envs\death\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
d = {}

def mapping():
    for i in colNames(data):
        a = raw_input('Do you want to analyze ' + i + ' ?\t')
        if a == 'y':
            d[i] = {'type': raw_input('.. and data type?')}
        else:
            d[i]= {'index':'not_analyzed','type': raw_input('.. and data type?\t')}
    return d

settings = {
    'records':{
        'properties':
            mapping()
    }
}
# Out:
# Do you want to analyze Age ?	n
# .. and data type?	integer
# Do you want to analyze County ?	n
# .. and data type?	string
# Do you want to analyze Date ?	n
# .. and data type?	date
# Do you want to analyze Description ?	y
# .. and data type?string
# Do you want to analyze Education ?	n
# .. and data type?	string
# Do you want to analyze Message ?	y
# .. and data type?string
# Do you want to analyze Mid ?	n
# .. and data type?	integer
# Do you want to analyze OILink ?	n
# .. and data type?	string
# Do you want to analyze OLastStatement ?	n
# .. and data type?	string
# Do you want to analyze Race ?	n
# .. and data type?	string
# Do you want to analyze firstName ?	n
# .. and data type?	string
# Do you want to analyze lastName ?	n
# .. and data type?	string
# Do you want to analyze MessageWords ?	y
# .. and data type?string
# Do you want to analyze DescriptionWords ?	y
# .. and data type?string
# Do you want to analyze MessageSenti ?	n
# .. and data type?	integer
# Do you want to analyze DescriptionSenti ?	n
# .. and data type?	integer

# %%
es = ElasticSearch('http://localhost:9200')

index = "death"
doc = "death.a"

# %%
try :
    es.delete_index(index)
except :
    pass

es.create_index(index, settings={'mappings': settings})
records = data.where(pd.notnull(data), None).T.to_dict()
list_records = [records[it] for it in records]

# %%
es.bulk_index(index,doc,list_records)
# Out:
# {u'errors': False,
#  u'items': [{u'create': {u'_id': u'AVTtOKO2gxmujOtvX635',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX636',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX637',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX638',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX639',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX63-',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX63_',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64A',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64B',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64C',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64D',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64E',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64F',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64G',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64H',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64I',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64J',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64K',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64L',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64M',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64N',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64O',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64P',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64Q',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64R',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64S',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64T',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64U',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64V',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64W',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64X',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64Y',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64Z',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64a',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64b',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64c',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64d',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64e',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64f',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64g',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64h',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64i',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64j',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64k',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64l',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64m',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64n',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64o',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64p',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64q',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64r',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64s',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64t',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO2gxmujOtvX64u',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX64v',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX64w',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX64x',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX64y',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX64z',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX640',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX641',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX642',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX643',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX644',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX645',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX646',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX647',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX648',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX649',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX64-',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX64_',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65A',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65B',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65C',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65D',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65E',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65F',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65G',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65H',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65I',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65J',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65K',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65L',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65M',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65N',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65O',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65P',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65Q',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65R',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65S',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65T',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65U',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65V',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65W',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65X',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65Y',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65Z',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65a',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65b',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65c',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65d',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65e',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65f',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65g',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65h',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65i',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65j',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65k',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65l',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65m',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65n',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65o',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65p',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65q',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65r',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65s',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65t',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65u',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65v',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65w',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65x',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65y',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65z',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX650',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX651',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX652',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX653',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX654',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX655',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX656',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX657',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX658',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX659',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65-',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX65_',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66A',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66B',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66C',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66D',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66E',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66F',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66G',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66H',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66I',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66J',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66K',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66L',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66M',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66N',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66O',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66P',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66Q',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66R',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66S',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66T',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66U',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66V',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66W',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66X',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66Y',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66Z',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66a',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66b',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66c',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66d',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66e',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66f',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66g',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66h',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66i',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66j',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66k',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66l',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66m',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66n',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66o',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66p',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66q',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66r',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66s',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66t',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66u',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66v',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66w',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66x',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66y',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66z',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX660',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX661',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX662',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX663',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX664',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX665',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX666',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX667',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX668',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX669',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66-',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX66_',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX67A',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO3gxmujOtvX67B',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67C',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67D',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67E',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67F',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67G',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67H',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67I',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67J',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67K',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67L',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67M',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67N',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67O',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67P',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67Q',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67R',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67S',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67T',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67U',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67V',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67W',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67X',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67Y',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67Z',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67a',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67b',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67c',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67d',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67e',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67f',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67g',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67h',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67i',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO4gxmujOtvX67j',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
# ...
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_E',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_F',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_G',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_H',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_I',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_J',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_K',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_L',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_M',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_N',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_O',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_P',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_Q',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_R',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_S',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_T',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_U',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_V',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_W',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_X',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_Y',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_Z',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_a',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_b',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_c',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_d',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_e',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_f',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_g',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_h',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_i',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_j',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_k',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_l',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_m',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_n',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_o',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_p',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_q',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_r',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_s',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_t',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_u',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_v',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_w',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_x',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_y',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_z',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_0',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_1',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_2',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_3',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_4',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_5',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_6',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_7',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_8',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_9',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6_-',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX6__',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AA',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AB',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AC',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AD',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AE',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AF',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AG',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AH',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AI',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AJ',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AK',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AL',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AM',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AN',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AO',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AP',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AQ',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}},
#   {u'create': {u'_id': u'AVTtOKO5gxmujOtvX7AR',
#     u'_index': u'death',
#     u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#     u'_type': u'death.a',
#     u'_version': 1,
#     u'status': 201}}],
#  u'took': 488}
